# %%
import matplotlib.pyplot as plt

# Data for the percentage changes for each company
companies = ['COST', 'WMT', 'TGT', 'ACI']
percentage_changes_cost = [33.23660907,  147.36217753, 198.14033632, 110.18201134, 121.66975336] # Costco
percentage_changes_wmt = [16.38106793,  34.37372705, 48.34761322, 42.18686353, 85.61811506]  # WMT
percentage_changes_tgt = [33.23660907,  147.36217753, 198.14033632, 110.18201134, 121.66975336]  # TGT
percentage_changes_aci = [19.48387097,  126.9032129, 25.80645161, 34.51612903]  # ACI
months = ['After 12 Months', 'After 24 Months', 'After 36 Months', 'After 48 Months', 'After 60 Months']

import matplotlib.pyplot as plt

# Data for the percentage changes for each company
companies = ['COST', 'WMT', 'TGT', 'ACI']
percentage_changes_cost = [33.23660907,  147.36217753, 198.14033632, 110.18201134, 121.66975336]  # Sample data for COST
percentage_changes_wmt = [40,  130, 160, 90, 110]  # Sample data for WMT
percentage_changes_tgt = [30,  120, 170, 100, 105]  # Sample data for TGT
percentage_changes_aci = [35,  140, 180, 95]  # Sample data for ACI (missing one value)
months = ['After 12 Months', 'After 24 Months', 'After 36 Months', 'After 48 Months', 'After 60 Months']

# Plotting the bar chart
plt.figure(figsize=(10, 6))

bar_width = 0.2  # Width of each bar
index = range(len(months))

plt.bar(index, percentage_changes_cost, width=bar_width, label='COST', color='skyblue')
plt.bar([i + bar_width for i in index], percentage_changes_wmt, width=bar_width, label='WMT', color='orange')
plt.bar([i + 2 * bar_width for i in index], percentage_changes_tgt, width=bar_width, label='TGT', color='green')
plt.bar([i + 3 * bar_width for i in index[:len(percentage_changes_aci)]], percentage_changes_aci, width=bar_width, label='ACI', color='red')  # Adjusting the index range for ACI

# Adding labels and title
plt.xlabel('Length of Investment')
plt.ylabel('Percentage Change')
plt.title('Percentage Change to Stock Price Over Time for Different Companies')
plt.xticks([i + 1.5 * bar_width for i in index], months, rotation=90)
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()
